# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.axes()
size = 1024
out5 = [0] * size
out10 = [0] * size
out20 = [0] * size
out100 = [0] * size
for i in range(size):
    out5[i] = i
    out10[i] = i
    out20[i] = i
    out100[i] = i
x = 0
for y in out5:
    y = 1 / (1 + ((size/2)/(x+1))**5)
    x+=1
x = 0
for y in out10:
    y = 1 / (1 + ((size/2)/(x+1))**10)
    x+=1
x = 0
for y in out100:
    y = 1 / (1 + ((size/2)/(x+1))**100)
    x+=1
ax.plot(out5)

# %%
fig2 = plt.figure()
ax2 = plt.axes()
ax2.plot(out10)

# %%
fig3 = plt.figure()
ax3 = plt.axes()
ax3.plot(out100)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import skimage.filters as f
from skimage import exposure
import skimage.io as io
from scipy import fftpack as ff
from PIL import Image

# %%
array = np.zeros((128,128))

# %%
for i in range(128):
    for j in range(128):
        if (i % 8 < 4): 
            array[i][j] = 1

# %%
plt.imshow(array)

# %%
imgDFT = ff.fft2(array)
S = np.abs(imgDFT) 
Fc = ff.fftshift(S)

# %%
plt.imshow(Fc)
